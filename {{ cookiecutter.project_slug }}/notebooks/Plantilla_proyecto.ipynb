# %% [markdown]
# # TITULO DEL PROYECTO

# %% [markdown]
# ## 1-Análisis y procesamiento de la data

# %% [markdown]
# Escribir de qué trata el proyecto

# %% [markdown]
# undefined. Instalación de Librerías

# %% [markdown]
# Escriba de que trata el numeral

# %%
#Escriba aquí el codigo python

# %% [markdown]
# 2. Procesamiento de Datos

# %% [markdown]
# Escriba de que trata el numeral

# %%
#Escriba aquí el codigo python

# %% [markdown]
# 3. Visualización de Datos

# %% [markdown]
# Escriba de que trata el numeral

# %%
#Escriba aquí el codigo python

# %% [markdown]
# ## 2-Conclusiones del análisis

# %% [markdown]
# Las conclusiones del analisis de los datos fueron son:

# %% [markdown]
# -

# %% [markdown]
# ## 3-Referencias bibliográficas

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2fd8faa7-38b2-4b26-a4e3-370c90fd61aa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
